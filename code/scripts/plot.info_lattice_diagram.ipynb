# %%
#########################
# Include Headers
#########################

using LinearAlgebra
using Arpack
using CairoMakie


include("../header/.src/circuit/brickwall.jl")
include("../header/.src/plotmods/colorschemes_mods.jl")
include("../header/.src/random_matrices/random_matrices.jl")
include("../header/.src/measurements/projectors.jl")
include("../header/.src/info_lattice/info_lattice.jl")
include("../header/.src/info_lattice/draw_info_lattice.jl")

# %%
  

    L=8
    theta=0.0

    cmap=Reverse(:navia)
    fig = Figure(size = (3200, 1200), fontsize = 12)


    #PM-MBL

    epsilon=1.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[1, 1], aspect = DataAspect()
            , title="Paramagnetic-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[1, 1],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    


    #DTC-MBL

    epsilon=0.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[2, 1], aspect = DataAspect()
            , title="DTC-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[2, 1],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    

   #PM-MBL

    epsilon=1.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[1, 2], aspect = DataAspect()
            , title="Paramagnetic-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[1, 2],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    


    #DTC-MBL

    epsilon=0.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[2, 2], aspect = DataAspect()
            , title="DTC-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[2, 2],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    
       #PM-MBL

    epsilon=1.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[1, 3], aspect = DataAspect()
            , title="Paramagnetic-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[1, 3],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    


    #DTC-MBL

    epsilon=0.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[2, 3], aspect = DataAspect()
            , title="DTC-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[2, 3],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    
       #PM-MBL

    epsilon=1.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[1, 4], aspect = DataAspect()
            , title="Paramagnetic-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[1, 4],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    


    #DTC-MBL

    epsilon=0.0
    infolattice = info_lattice_brickwall(L, theta, epsilon)

    g=1.0-epsilon
  
    ax = Axis(fig[2, 4], aspect = DataAspect()
            , title="DTC-MBL (g=$(g))"
            ,xticks = (1.5:0.5:(length(infolattice[1])+0.5), string.(1:0.5:(length(infolattice[1])))), 
            yticks = ((1:(length(infolattice[1]))).*(sqrt(3)/2), string.(1:(length(infolattice[1]))))
            )

    a = Point2f(1, 0)
    b = Point2f(0.5, sqrt(3)/2)

    xlims!(ax, 0, length(infolattice[1])+2)
    ylims!(ax, 0, length(infolattice))

   
    radius = 0.55  # Size of the hexagons
    hex_vertices = [Point2f(radius * cos(θ), radius * sin(θ)) for θ in π/6:π/3:2π]

    for (nb, line) in enumerate(infolattice)
        for (na, val) in enumerate(line)
            coord = na * a + nb * b
            poly = Polygon([v + coord for v in hex_vertices])
            p=val
            # Add rounded effect using stroke
            poly!(ax, poly,  color = val, colormap = cmap, colorrange = (1, 0), strokewidth = 1.5, strokecolor = :black)
        end

        
        ax_inset = Axis(fig[2, 4],
        width=Relative(0.28),
        height=Relative(0.22),
        halign=0.14,
        valign=0.95,
        title="Total bits of information per level",
        xlabel=L"l",
        ylabel=L"I(l)",
        xticks = ((1:(length(infolattice[1]))), string.(1:(length(infolattice[1])))))
        
    inset_info_lattice(infolattice, ax_inset)
                  
    end
    


    # Colorbar


    Colorbar(fig[1,5] , colormap=cmap,                      #Colorbar
    ticks = 0.0:0.1:1.0)                       #Colorbar ticks
    
    
    Colorbar(fig[2,5] , colormap=cmap,                      #Colorbar
    ticks = 0.0:0.1:1.0)                       #Colorbar ticks
    
    
    
    
    
    
    fig

# %%
save("../../tex/.src/images/info_lattice_diagram_timecrystals.png", fig, px_per_unit=4)
