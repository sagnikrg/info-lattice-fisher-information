# %%
#########################
# Include Headers
#########################

using LinearAlgebra
using HDF5
using Arpack
using CairoMakie


include("../header/.src/circuit/brickwall.jl")
include("../header/.src/circuit/hiesenberg.jl")
#include("../header/.src/circuit/time-crystals.jl")
include("../header/.src/hdf5/hdf5Mods.jl")
include("../header/.src/plotmods/colorschemes_mods.jl")
include("../header/.src/random_matrices/random_matrices.jl")
include("../header/.src/measurements/projectors.jl")
include("../header/.src/info_lattice/info_lattice.jl")
include("../header/.src/lazadires_diagram/lazadires_diagram.jl")
# Out:
# LazadiresDiagramPlot (generic function with 1 method)

# %%
L=8
theta=1.5

A=circuit_heisenberg(L, theta)

draw_info_lattice(info_lattice(A))

# %%
#### attrs-author

file=h5open("../data/hiesenberg_transition_ordpar.hdf5","cw")
set_hdf5_attributes(file)
close(file)
;
# Out:
# ┌ Warning: Pkg.installed() is deprecated
# └ @ Pkg C:\Users\Ritam\.julia\juliaup\julia-1.11.7+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Pkg\src\Pkg.jl:785

# %%
#### attrs-model

file=h5open("../data/hiesenberg_transition_ordpar.hdf5","cw")
 attrs = HDF5.attributes(file)

 attrs["[Model] 1. Unitary"]="exp(- i J ZZ + \theta/2 (XX+YY))exp(- i h_i Z)"

 attrs["[Model] 2. J"]="1"

 attrs["[Model] 3. Tuning parameter"]="\theta"

 attrs["[Model] 4. Range of h"]="[0, 2pi], Uniform"

 attrs["[Model] 5. Order parameters"]="eigenvalues, info_lattice"

 attrs["4. METADATA"]=["This file contains raw eigen data and information lattice of individual eigenstates of the XXZ unitary, we aim to establish the critical point of the ETH-MBL transition with the aim to establish the unitary as a candidate driving scheme for the fisher information based probe for measurment induced phase transition as proposed by Arnau, Silvia and Xhek.
 
 We save the realistion of h for each realisation and since this is the only source of random-ness, results can be exactly reproduced. Relevant functions used to generate the circuit will be provided as a script. info-lattice Data for various projected eigenstates to be added in a seperate file"]



close(file)

# %%
## towards the iterative script for collecting eigen-data

L=8
N=2^L





theta=0.2;
itr=1

file=h5open("../data/hiesenberg_transition_ordpar.hdf5","cw")

## Drawing the Background Disorder

h=rand(L)*2*pi;


## Writing the disorder strength

file["L$(L)/theta$(theta)/Itr$(itr)/h"]=h;

## Building Ckt, Getting Eigenstates

A=circuit_heisenberg(L,theta,h)
global eigvals,eigvecs= eigen(A)


## Writing eigen values

file["L$(L)/theta$(theta)/Itr$(itr)/eigvals"]=eigvals;



## Writing info-lattice of individual eigenstates


for i in 1:N
        state=eigvecs[i,:]
        info_lattice_state=info_lattice(state)
        file["L$(L)/theta$(theta)/Itr$(itr)/info_lattice/eigvec_$(i)"]=info_lattice_state
end


close(file)
# Out:
# MethodError: no method matching hdf5_type_id(::Type{Ptr{Nothing}}, ::Val{false})
#
# This error has been manually thrown, explicitly, so the method may exist but be intentionally marked as unimplemented.
#
#
#
# Closest candidates are:
#
#   hdf5_type_id(::Type{T}, ::Val{false}) where T
#
#    @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:81
#
#   hdf5_type_id(::Type{T}) where T
#
#    @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:71
#
#   hdf5_type_id(::Type{T}, !Matched::Val{true}) where T
#
#    @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:72
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#   [1] hdf5_type_id(::Type{Ptr{Nothing}}, isstruct::Val{false})
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:81
#
#   [2] hdf5_type_id(::Type{Ptr{Nothing}})
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:71
#
#   [3] hdf5_type_id(::Type{MemoryRef{Float64}}, isstruct::Val{true})
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:76
#
#   [4] hdf5_type_id
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:71 [inlined]
#
#   [5] hdf5_type_id(::Type{Vector{Float64}}, isstruct::Val{true})
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:76
#
#   [6] hdf5_type_id
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:71 [inlined]
#
#   [7] datatype
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\typeconversions.jl:69 [inlined]
#
#   [8] create_dataset(parent::HDF5.File, name::String, data::Vector{Vector{Float64}}; pv::@Kwargs{})
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\datasets.jl:296
#
#   [9] create_dataset
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\datasets.jl:293 [inlined]
#
#  [10] write_dataset(parent::HDF5.File, name::String, data::Vector{Vector{Float64}}; pv::@Kwargs{})
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\datasets.jl:318
#
#  [11] write_dataset
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\datasets.jl:315 [inlined]
#
#  [12] write
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\datasets.jl:342 [inlined]
#
#  [13] #setindex!#115
#
#     @ C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\highlevel.jl:107 [inlined]
#
#  [14] setindex!(parent::HDF5.File, val::Vector{Vector{Float64}}, path::String)
#
#     @ HDF5 C:\Users\Ritam\.julia\packages\HDF5\Z859u\src\highlevel.jl:90
#
#  [15] top-level scope
#
#     @ c:\Users\Ritam\OneDrive\Documents\Codespaces\info-lattice-fisher-information\code\scripts\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:42
